# %%
import numpy as np

# %%
import tensorflow as tf

# %%
# loading data : np.loadtxt()

# %%
# converting data : continuous -> categorical

# %%
# build model (sklearn?)

# %%
# training & test

# %%
path = "C:\\Users\\KangYounKook\\Desktop\\ML_Study"

# %%
txtfile = "\\data3t.txt"

# %%
name = path+txtfile
name
# Out:
# 'C:\\Users\\KangYounKook\\Desktop\\ML_Study\\data3t.txt'

# %%
import pandas as pd

# %%
pathName = path + "\\input4_20_c.csv"
print(pathName)
# Out:
# C:\Users\KangYounKook\Desktop\ML_Study\input4_20_c.csv

# %%
data = pd.read_csv(pathName)

# %%
data
# Out:
#       Section1219  Section3753  Section1230  Section4586  Section4327  \
# 0               3           10            3            6            6
# 1               3           10            6           10            7
# 2               2            9            6            8            4
# 3               1            9            2            7            4
# 4               3           10            6           10            4
# 5               3           10            2           10            4
# 6               3            8            6            6            5
# 7               3           10            3           10            7
# 8               3           10            2           10            4
# 9               2           10            6           10            4
# 10              3           10            2            7           10
# 11              5            8            4            6            4
# ...

# %%
#d1=data.drop(0)

# %%
#data.iloc[0, 1:3]

# %%
#data.iloc[0,]

# %%
#data['Section1219'][0:5]

# %%
X = np.array(data)

# %%
y1 = np.array(data['Section1219'])
y2 = np.array(data['Section537'])
y3 = np.array(data['Section583'])
y4 = np.array(data['Section999'])

# %%
y = np.c_[y1,y2,y3,y4]
y.shape
# Out:
# (1440, 4)

# %%
print(y.shape)
print(y[:,0:1].shape)
# Out:
# (1440, 4)
# (1440, 1)

# %%
Xt = X[0:1000]
Xval = X[1000:1200]

# %%
yt = y[1:1001]
yval = y[1001:1201]

# %%
#Xtrain = data.iloc[0:119]

# %%
from sklearn.linear_model import LinearRegression

# %%
#reg = LinearRegression()

# %%
#reg.fit?

# %%
#lr = reg.fit(Xt[:,0:5],y1t)

# %%
#reg.coef_

# %%
#reg.intercept_

# %%
#lr.score(Xt[:,0:5],y1t)

# %%
from sklearn import linear_model

# %%
from sklearn.cross_validation import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
logit = linear_model.LogisticRegression()

# %%
lr = logit.fit(Xt[:,0:5],yt[:,0:1])
# Out:
# C:\Users\KangYounKook\Anaconda3\envs\py35\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
lr.score(Xt[:,0:5],yt[:,0:1])
# Out:
# 0.49099999999999999

# %%
lr.score(Xval[:,0:5],yval[:,0:1])
# Out:
# 0.57499999999999996

# %%
# section

# %%
for i in range(4):
    ll = logit.fit(Xt[:,i:i+5],yt[:,i:i+1])
    print(i)
    print(ll.score(Xt[:,i:i+5],yt[:,i:i+1]))
    print(ll.score(Xval[:,i:i+5],yval[:,i:i+1]))
# Out:
# 0
# 0.491
# 0.575
# 1
# 0.399
# 0.405
# 2
# 0.321
# 0.35
# 3
# 0.233
# 0.15
# C:\Users\KangYounKook\Anaconda3\envs\py35\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
